# %% [markdown]
# <a href="https://colab.research.google.com/github/rombaux/PyTorch-GAN/blob/master/tfe_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***MONTAGE DU GDRIVE***

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # GIT DOWNLOAD

# %%
# !git clone https://github.com/rombaux/PyTorch-GAN

# %%
cd /content/PyTorch-GAN
# Out:
# /content/PyTorch-GAN

# %% [markdown]
# # *GIT MISE à JOUR*

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# From https://github.com/rombaux/PyTorch-GAN
#    fe7c1b2..8192a2c  master     -> origin/master
# Updating fe7c1b2..8192a2c
# Fast-forward
#  implementations/cgan/cgan_genimg.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git log -n 3

# %% [markdown]
# # INSTALLATION des Dépendances

# %%
cd PyTorch-GAN/

# %%
# !sudo pip3 install -r requirements.txt

# %% [markdown]
# # GENERATEUR

# %%
cd /content/PyTorch-GAN/implementations/cgan/
# Out:
# /content/PyTorch-GAN/implementations/cgan

# %%
# !python3 cgan_genimg.py --n_epochs 2500 --gennumber 98765432101234567890 --genidlabel 8
# Out:
# Namespace(b1=0.5, b2=0.999, batch_size=64, channels=1, genidlabel=8, gennumber=98765432101234567890, img_size=32, latent_dim=100, lr=0.0002, n_classes=10, n_cpu=8, n_epochs=2500, sample_interval=400)
# Path is created as /content/gdrive/My Drive/TFE/images/2019-07-24_22-50
# [Epoch 0/2500] [Batch 0/938] [D loss: 0.536570] [G loss: 0.962047]
# nombre : 98765432101234567890 generated
# [Epoch 0/2500] [Batch 400/938] [D loss: 0.053448] [G loss: 0.683232]
# nombre : 98765432101234567890 generated
# [Epoch 0/2500] [Batch 800/938] [D loss: 0.035890] [G loss: 0.885317]
# nombre : 98765432101234567890 generated
# [Epoch 1/2500] [Batch 262/938] [D loss: 0.030071] [G loss: 0.769904]
# nombre : 98765432101234567890 generated
# [Epoch 1/2500] [Batch 662/938] [D loss: 0.037503] [G loss: 0.730123]
# nombre : 98765432101234567890 generated
# [Epoch 2/2500] [Batch 124/938] [D loss: 0.060645] [G loss: 0.619915]
# nombre : 98765432101234567890 generated
# ...

# %%
 # !python3 cgan01.py --n_epochs 10

# %%
cd images/
# Out:
# /content/PyTorch-GAN/implementations/cgan/images

# %%
pwd
# Out:
# '/content/PyTorch-GAN/implementations/cgan/images'

# %%
cd /content/gdrive/My\ Drive/TFE/images/
# Out:
# /content/gdrive/My Drive/TFE/images

# %%
cd gdrive/My\ Drive
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive'
# /content/PyTorch-GAN/implementations/cgan/images

# %%
# !ls -ltr
# Out:
# total 914
# -rw------- 1 root root 270158 Jul 22 23:00 0.png
# -rw------- 1 root root 183547 Jul 22 23:00 400.png
# -rw------- 1 root root 168228 Jul 22 23:00 800.png
# -rw------- 1 root root 165332 Jul 22 23:00 1200.png
# -rw------- 1 root root 147385 Jul 22 23:00 1600.png

# %%
cd 2019-07-22_23-00/
# Out:
# /content/gdrive/My Drive/TFE/images/2019-07-22_23-00

# %%
 import time
 date_string = time.strftime("%Y-%m-%d")
 print(date_string)
# Out:
# 2019-07-22

# %%
cd /
# Out:
# /

# %%
cd /content/
# Out:
# /content

# %%
# !find . -mtime 0

# %%
cd /content/PyTorch-GAN/data/mnist/MNIST/processed/
# Out:
# /content/PyTorch-GAN/data/mnist/MNIST/processed

# %%
# !ls -al
# Out:
# total 54152
# drwxr-xr-x 2 root root     4096 Jul 24 17:53 .
# drwxr-xr-x 4 root root     4096 Jul 24 17:53 ..
# -rw-r--r-- 1 root root  7920450 Jul 24 17:53 test.pt
# -rw-r--r-- 1 root root 47520450 Jul 24 17:53 training.pt
